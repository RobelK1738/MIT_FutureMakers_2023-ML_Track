# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-RobelK1738/blob/main/Module_07_Regression_Loss_Functions/Regression_Loss_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# # Objective
# * To introduce you to loss functions.

# %% [markdown]
# # Loss Functions

# %% [markdown]
# Loss functions define what a good prediction is and isn’t. Choosing the right loss function dictates how well your estimator (machine learning model) will be. The criteria by which an estimator is scrutinized is its performance - how accurate the model's decisions are. This calls for a way to measure how far a particular iteration of the model is from the actual values. This is where loss functions come into play.
#
# Loss functions measure how far an estimated value is from its true value. A loss function maps decisions to their associated costs. Loss functions are not fixed, they change depending on the task in hand and the goal to be met.
#
# Worth to note we can speak of different kind of loss functions: **regression loss** functions and **classification loss** functions.
#
# Regression loss function describes the difference between the values that a model is predicting and the actual values of the labels. So the loss function has a meaning on a labeled data when we compare the prediction to the label at a single point of time. This loss function is often called the error function or the error formula. Typical error functions we use for regression models are L1 and L2, Huber loss, Quantile loss, log cosh loss.
#
# **Note**: L1 loss is also know as Mean Absolute Error. L2 Loss is also know as Mean Square Error or Quadratic loss.
#
# Loss functions for classification represent the price paid for inaccuracy of predictions in classification problems (problems of identifying which category a particular observation belongs to). To name a few: log loss, focal loss, exponential loss, hinge loss, relative entropy loss and other.
#
# *Note*: While more commonly used in regression, the square loss function can be re-written and utilized for classification.

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Regression Losses
#
# Remember, in regression, the output would be a real value. We need some loss functions which compares two real values.

# %%
(train_features, train_labels), (test_features, test_labels) = keras.datasets.boston_housing.load_data()

# get per-feature statistics (mean, standard deviation) from the training set to normalize by
train_mean = np.mean(train_features, axis=0)
train_std = np.std(train_features, axis=0)
train_features = (train_features - train_mean) / train_std
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %% [markdown]
# ## Mean Squared Error [MSE]
#
# As the name suggests, Mean square error is measured as the average of squared difference between predictions and actual observations. It’s only concerned with the average magnitude of error irrespective of their direction.
#
# However, due to squaring, predictions which are far away from actual values are penalized heavily in comparison to less deviated predictions. Plus MSE has nice mathematical properties which makes it easier to calculate gradients.
#
# Let's assume there are $n$ data samples, for $i^{th}$ sample; the actual output is $y_i$ and $\hat{y}_i$ is the estimated output from the regression model.
#
# We first square the difference between the original and estimated output with $(y_i - \hat{y}_i)^2$. Then we take sum of the squared difference for all the samples. And finally divide it by the total count of samples, which is $n$.
#
# $$MSE = \frac{\sum_{i=1}^{n}(y_i - \hat{y}_i)^2}{n}$$

# %%
model = keras.Sequential([
        tf.keras.layers.Dense(10, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(50, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(20, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(1)
    ])

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mse'])

model.fit(train_features, train_labels, epochs=250, validation_split = 0.1)
# Out:
# Epoch 1/250
# 12/12 [==============================] - 8s 21ms/step - loss: 556.8895 - mse: 556.8895 - val_loss: 455.4187 - val_mse: 455.4187
# Epoch 2/250
# 12/12 [==============================] - 0s 6ms/step - loss: 521.1682 - mse: 521.1682 - val_loss: 414.6708 - val_mse: 414.6708
# Epoch 3/250
# 12/12 [==============================] - 0s 7ms/step - loss: 468.5334 - mse: 468.5334 - val_loss: 354.8643 - val_mse: 354.8643
# Epoch 4/250
# 12/12 [==============================] - 0s 7ms/step - loss: 392.5182 - mse: 392.5182 - val_loss: 271.2914 - val_mse: 271.2914
# Epoch 5/250
# 12/12 [==============================] - 0s 7ms/step - loss: 292.2132 - mse: 292.2132 - val_loss: 166.9482 - val_mse: 166.9482
# Epoch 6/250
# 12/12 [==============================] - 0s 5ms/step - loss: 178.2210 - mse: 178.2210 - val_loss: 76.5414 - val_mse: 76.5414
# Epoch 7/250
# 12/12 [==============================] - 0s 5ms/step - loss: 101.0188 - mse: 101.0188 - val_loss: 42.0863 - val_mse: 42.0863
# Epoch 8/250
# 12/12 [==============================] - 0s 6ms/step - loss: 75.7732 - mse: 75.7732 - val_loss: 37.8116 - val_mse: 37.8116
# Epoch 9/250
# 12/12 [==============================] - 0s 6ms/step - loss: 62.9565 - mse: 62.9565 - val_loss: 30.4405 - val_mse: 30.4405
# Epoch 10/250
# 12/12 [==============================] - 0s 5ms/step - loss: 53.2328 - mse: 53.2328 - val_loss: 25.7733 - val_mse: 25.7733
# Epoch 11/250
# 12/12 [==============================] - 0s 8ms/step - loss: 48.2720 - mse: 48.2720 - val_loss: 24.9125 - val_mse: 24.9125
# Epoch 12/250
# 12/12 [==============================] - 0s 6ms/step - loss: 44.0034 - mse: 44.0034 - val_loss: 23.9716 - val_mse: 23.9716
# Epoch 13/250
# 12/12 [==============================] - 0s 7ms/step - loss: 40.9981 - mse: 40.9981 - val_loss: 23.0366 - val_mse: 23.0366
# Epoch 14/250
# 12/12 [==============================] - 0s 5ms/step - loss: 38.5490 - mse: 38.5490 - val_loss: 22.7625 - val_mse: 22.7625
# Epoch 15/250
# 12/12 [==============================] - 0s 5ms/step - loss: 36.2630 - mse: 36.2630 - val_loss: 21.4360 - val_mse: 21.4360
# Epoch 16/250
# 12/12 [==============================] - 0s 5ms/step - loss: 34.4409 - mse: 34.4409 - val_loss: 20.9650 - val_mse: 20.9650
# Epoch 17/250
# 12/12 [==============================] - 0s 7ms/step - loss: 32.6712 - mse: 32.6712 - val_loss: 20.8160 - val_mse: 20.8160
# Epoch 18/250
# 12/12 [==============================] - 0s 5ms/step - loss: 31.0001 - mse: 31.0001 - val_loss: 19.8366 - val_mse: 19.8366
# Epoch 19/250
# 12/12 [==============================] - 0s 5ms/step - loss: 29.5811 - mse: 29.5811 - val_loss: 19.3112 - val_mse: 19.3112
# Epoch 20/250
# 12/12 [==============================] - 0s 7ms/step - loss: 28.3624 - mse: 28.3624 - val_loss: 19.0877 - val_mse: 19.0877
# Epoch 21/250
# 12/12 [==============================] - 0s 5ms/step - loss: 27.0330 - mse: 27.0330 - val_loss: 17.9736 - val_mse: 17.9736
# Epoch 22/250
# 12/12 [==============================] - 0s 7ms/step - loss: 26.1432 - mse: 26.1432 - val_loss: 18.0302 - val_mse: 18.0302
# Epoch 23/250
# 12/12 [==============================] - 0s 5ms/step - loss: 24.8467 - mse: 24.8467 - val_loss: 17.6469 - val_mse: 17.6469
# Epoch 24/250
# 12/12 [==============================] - 0s 7ms/step - loss: 23.8282 - mse: 23.8282 - val_loss: 17.3107 - val_mse: 17.3107
# Epoch 25/250
# 12/12 [==============================] - 0s 5ms/step - loss: 22.9239 - mse: 22.9239 - val_loss: 16.9854 - val_mse: 16.9854
# Epoch 26/250
# 12/12 [==============================] - 0s 6ms/step - loss: 22.1130 - mse: 22.1130 - val_loss: 16.5901 - val_mse: 16.5901
# Epoch 27/250
# 12/12 [==============================] - 0s 7ms/step - loss: 21.4078 - mse: 21.4078 - val_loss: 16.2215 - val_mse: 16.2215
# Epoch 28/250
# 12/12 [==============================] - 0s 5ms/step - loss: 20.7737 - mse: 20.7737 - val_loss: 16.6699 - val_mse: 16.6699
# Epoch 29/250
# 12/12 [==============================] - 0s 8ms/step - loss: 20.1906 - mse: 20.1906 - val_loss: 15.9577 - val_mse: 15.9577
# Epoch 30/250
# 12/12 [==============================] - 0s 7ms/step - loss: 19.5868 - mse: 19.5868 - val_loss: 15.2253 - val_mse: 15.2253
# Epoch 31/250
# 12/12 [==============================] - 0s 7ms/step - loss: 19.1052 - mse: 19.1052 - val_loss: 15.3764 - val_mse: 15.3764
# Epoch 32/250
# 12/12 [==============================] - 0s 7ms/step - loss: 18.6873 - mse: 18.6873 - val_loss: 15.1323 - val_mse: 15.1323
# Epoch 33/250
# 12/12 [==============================] - 0s 6ms/step - loss: 18.1338 - mse: 18.1338 - val_loss: 15.0238 - val_mse: 15.0238
# Epoch 34/250
# 12/12 [==============================] - 0s 6ms/step - loss: 17.8002 - mse: 17.8002 - val_loss: 15.0639 - val_mse: 15.0639
# Epoch 35/250
# 12/12 [==============================] - 0s 7ms/step - loss: 17.3460 - mse: 17.3460 - val_loss: 15.4696 - val_mse: 15.4696
# Epoch 36/250
# 12/12 [==============================] - 0s 7ms/step - loss: 17.1447 - mse: 17.1447 - val_loss: 15.1257 - val_mse: 15.1257
# Epoch 37/250
# 12/12 [==============================] - 0s 7ms/step - loss: 16.7986 - mse: 16.7986 - val_loss: 14.0829 - val_mse: 14.0829
# Epoch 38/250
# 12/12 [==============================] - 0s 6ms/step - loss: 16.5486 - mse: 16.5486 - val_loss: 14.7660 - val_mse: 14.7660
# Epoch 39/250
# 12/12 [==============================] - 0s 6ms/step - loss: 15.9853 - mse: 15.9853 - val_loss: 14.4799 - val_mse: 14.4799
# Epoch 40/250
# 12/12 [==============================] - 0s 7ms/step - loss: 15.9540 - mse: 15.9540 - val_loss: 14.9170 - val_mse: 14.9170
# Epoch 41/250
# 12/12 [==============================] - 0s 5ms/step - loss: 15.5334 - mse: 15.5334 - val_loss: 14.0376 - val_mse: 14.0376
# Epoch 42/250
# 12/12 [==============================] - 0s 6ms/step - loss: 15.3110 - mse: 15.3110 - val_loss: 14.3015 - val_mse: 14.3015
# Epoch 43/250
# 12/12 [==============================] - 0s 7ms/step - loss: 15.0800 - mse: 15.0800 - val_loss: 14.0996 - val_mse: 14.0996
# Epoch 44/250
# 12/12 [==============================] - 0s 7ms/step - loss: 14.8468 - mse: 14.8468 - val_loss: 13.8050 - val_mse: 13.8050
# Epoch 45/250
# 12/12 [==============================] - 0s 6ms/step - loss: 14.6986 - mse: 14.6986 - val_loss: 14.0674 - val_mse: 14.0674
# Epoch 46/250
# 12/12 [==============================] - 0s 6ms/step - loss: 14.3805 - mse: 14.3805 - val_loss: 13.8290 - val_mse: 13.8290
# Epoch 47/250
# 12/12 [==============================] - 0s 6ms/step - loss: 14.2547 - mse: 14.2547 - val_loss: 13.5263 - val_mse: 13.5263
# Epoch 48/250
# 12/12 [==============================] - 0s 5ms/step - loss: 14.0111 - mse: 14.0111 - val_loss: 13.7452 - val_mse: 13.7452
# Epoch 49/250
# 12/12 [==============================] - 0s 5ms/step - loss: 13.9567 - mse: 13.9567 - val_loss: 13.5530 - val_mse: 13.5530
# Epoch 50/250
# 12/12 [==============================] - 0s 6ms/step - loss: 13.8093 - mse: 13.8093 - val_loss: 14.0295 - val_mse: 14.0295
# Epoch 51/250
# 12/12 [==============================] - 0s 7ms/step - loss: 13.5263 - mse: 13.5263 - val_loss: 13.5201 - val_mse: 13.5201
# Epoch 52/250
# 12/12 [==============================] - 0s 5ms/step - loss: 13.3603 - mse: 13.3603 - val_loss: 13.2360 - val_mse: 13.2360
# Epoch 53/250
# 12/12 [==============================] - 0s 6ms/step - loss: 13.2237 - mse: 13.2237 - val_loss: 13.5497 - val_mse: 13.5497
# Epoch 54/250
# 12/12 [==============================] - 0s 7ms/step - loss: 13.2541 - mse: 13.2541 - val_loss: 12.7794 - val_mse: 12.7794
# Epoch 55/250
# 12/12 [==============================] - 0s 6ms/step - loss: 12.9122 - mse: 12.9122 - val_loss: 13.5894 - val_mse: 13.5894
# Epoch 56/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.9045 - mse: 12.9045 - val_loss: 12.6904 - val_mse: 12.6904
# Epoch 57/250
# 12/12 [==============================] - 0s 6ms/step - loss: 12.6937 - mse: 12.6937 - val_loss: 12.9124 - val_mse: 12.9124
# Epoch 58/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.4951 - mse: 12.4951 - val_loss: 12.5219 - val_mse: 12.5219
# Epoch 59/250
# 12/12 [==============================] - 0s 6ms/step - loss: 12.3126 - mse: 12.3126 - val_loss: 13.0138 - val_mse: 13.0138
# Epoch 60/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.2216 - mse: 12.2216 - val_loss: 12.3867 - val_mse: 12.3867
# Epoch 61/250
# 12/12 [==============================] - 0s 6ms/step - loss: 12.1083 - mse: 12.1083 - val_loss: 12.2930 - val_mse: 12.2930
# Epoch 62/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.1704 - mse: 12.1704 - val_loss: 11.9503 - val_mse: 11.9503
# Epoch 63/250
# 12/12 [==============================] - 0s 6ms/step - loss: 11.7921 - mse: 11.7921 - val_loss: 12.5881 - val_mse: 12.5881
# Epoch 64/250
# 12/12 [==============================] - 0s 5ms/step - loss: 11.7737 - mse: 11.7737 - val_loss: 12.1610 - val_mse: 12.1610
# Epoch 65/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.6499 - mse: 11.6499 - val_loss: 11.6405 - val_mse: 11.6405
# Epoch 66/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.5572 - mse: 11.5572 - val_loss: 12.0429 - val_mse: 12.0429
# Epoch 67/250
# 12/12 [==============================] - 0s 9ms/step - loss: 11.4590 - mse: 11.4590 - val_loss: 11.8670 - val_mse: 11.8670
# Epoch 68/250
# 12/12 [==============================] - 0s 8ms/step - loss: 11.3273 - mse: 11.3273 - val_loss: 11.5443 - val_mse: 11.5443
# Epoch 69/250
# 12/12 [==============================] - 0s 9ms/step - loss: 11.3769 - mse: 11.3769 - val_loss: 11.8518 - val_mse: 11.8518
# Epoch 70/250
# 12/12 [==============================] - 0s 9ms/step - loss: 11.0655 - mse: 11.0655 - val_loss: 11.1249 - val_mse: 11.1249
# Epoch 71/250
# 12/12 [==============================] - 0s 9ms/step - loss: 11.2507 - mse: 11.2507 - val_loss: 11.5967 - val_mse: 11.5967
# Epoch 72/250
# 12/12 [==============================] - 0s 8ms/step - loss: 10.9994 - mse: 10.9994 - val_loss: 11.3290 - val_mse: 11.3290
# Epoch 73/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.8815 - mse: 10.8815 - val_loss: 11.2699 - val_mse: 11.2699
# Epoch 74/250
# 12/12 [==============================] - 0s 11ms/step - loss: 10.8153 - mse: 10.8153 - val_loss: 11.1162 - val_mse: 11.1162
# Epoch 75/250
# 12/12 [==============================] - 0s 10ms/step - loss: 10.9373 - mse: 10.9373 - val_loss: 11.3867 - val_mse: 11.3867
# Epoch 76/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.6171 - mse: 10.6171 - val_loss: 10.7719 - val_mse: 10.7719
# Epoch 77/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.5896 - mse: 10.5896 - val_loss: 10.9191 - val_mse: 10.9191
# Epoch 78/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.5294 - mse: 10.5294 - val_loss: 10.9801 - val_mse: 10.9801
# Epoch 79/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.4700 - mse: 10.4700 - val_loss: 10.8573 - val_mse: 10.8573
# Epoch 80/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.3129 - mse: 10.3129 - val_loss: 10.6968 - val_mse: 10.6968
# Epoch 81/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.3224 - mse: 10.3224 - val_loss: 10.8505 - val_mse: 10.8505
# Epoch 82/250
# 12/12 [==============================] - 0s 10ms/step - loss: 10.2009 - mse: 10.2009 - val_loss: 10.6055 - val_mse: 10.6055
# Epoch 83/250
# 12/12 [==============================] - 0s 9ms/step - loss: 10.1564 - mse: 10.1564 - val_loss: 10.4496 - val_mse: 10.4496
# Epoch 84/250
# 12/12 [==============================] - 0s 10ms/step - loss: 10.1014 - mse: 10.1014 - val_loss: 10.6226 - val_mse: 10.6226
# Epoch 85/250
# 12/12 [==============================] - 0s 11ms/step - loss: 10.0636 - mse: 10.0636 - val_loss: 10.5742 - val_mse: 10.5742
# Epoch 86/250
# 12/12 [==============================] - 0s 8ms/step - loss: 9.9893 - mse: 9.9893 - val_loss: 10.4408 - val_mse: 10.4408
# Epoch 87/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9891 - mse: 9.9891 - val_loss: 10.4682 - val_mse: 10.4682
# Epoch 88/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9662 - mse: 9.9662 - val_loss: 10.2553 - val_mse: 10.2553
# Epoch 89/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.8914 - mse: 9.8914 - val_loss: 10.2214 - val_mse: 10.2214
# Epoch 90/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.8538 - mse: 9.8538 - val_loss: 9.8566 - val_mse: 9.8566
# Epoch 91/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.7863 - mse: 9.7863 - val_loss: 10.1858 - val_mse: 10.1858
# Epoch 92/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.7400 - mse: 9.7400 - val_loss: 9.9146 - val_mse: 9.9146
# Epoch 93/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6294 - mse: 9.6294 - val_loss: 9.9222 - val_mse: 9.9222
# Epoch 94/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.6025 - mse: 9.6025 - val_loss: 10.0425 - val_mse: 10.0425
# Epoch 95/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6029 - mse: 9.6029 - val_loss: 9.8117 - val_mse: 9.8117
# Epoch 96/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6980 - mse: 9.6980 - val_loss: 10.0343 - val_mse: 10.0343
# Epoch 97/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.7173 - mse: 9.7173 - val_loss: 9.7639 - val_mse: 9.7639
# Epoch 98/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.6914 - mse: 9.6914 - val_loss: 10.2119 - val_mse: 10.2119
# Epoch 99/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.3880 - mse: 9.3880 - val_loss: 9.5118 - val_mse: 9.5118
# Epoch 100/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.6449 - mse: 9.6449 - val_loss: 9.5952 - val_mse: 9.5952
# Epoch 101/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.4319 - mse: 9.4319 - val_loss: 9.7169 - val_mse: 9.7169
# Epoch 102/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.5067 - mse: 9.5067 - val_loss: 9.5447 - val_mse: 9.5447
# Epoch 103/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2936 - mse: 9.2936 - val_loss: 9.4719 - val_mse: 9.4719
# Epoch 104/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.2802 - mse: 9.2802 - val_loss: 9.7414 - val_mse: 9.7414
# Epoch 105/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2151 - mse: 9.2151 - val_loss: 9.3007 - val_mse: 9.3007
# Epoch 106/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.2810 - mse: 9.2810 - val_loss: 9.4171 - val_mse: 9.4171
# Epoch 107/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.3153 - mse: 9.3153 - val_loss: 9.5542 - val_mse: 9.5542
# Epoch 108/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.1165 - mse: 9.1165 - val_loss: 9.3250 - val_mse: 9.3250
# Epoch 109/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.1107 - mse: 9.1107 - val_loss: 9.4909 - val_mse: 9.4909
# Epoch 110/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.1121 - mse: 9.1121 - val_loss: 9.3426 - val_mse: 9.3426
# Epoch 111/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.0828 - mse: 9.0828 - val_loss: 9.2977 - val_mse: 9.2977
# Epoch 112/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.0408 - mse: 9.0408 - val_loss: 9.3799 - val_mse: 9.3799
# Epoch 113/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0055 - mse: 9.0055 - val_loss: 9.1661 - val_mse: 9.1661
# Epoch 114/250
# 12/12 [==============================] - 0s 5ms/step - loss: 9.0470 - mse: 9.0470 - val_loss: 9.1555 - val_mse: 9.1555
# Epoch 115/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.9670 - mse: 8.9670 - val_loss: 9.1484 - val_mse: 9.1484
# Epoch 116/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0848 - mse: 9.0848 - val_loss: 9.1893 - val_mse: 9.1893
# Epoch 117/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.0965 - mse: 9.0965 - val_loss: 9.1664 - val_mse: 9.1664
# Epoch 118/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.8250 - mse: 8.8250 - val_loss: 9.0644 - val_mse: 9.0644
# Epoch 119/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.7745 - mse: 8.7745 - val_loss: 9.2413 - val_mse: 9.2413
# Epoch 120/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.7769 - mse: 8.7769 - val_loss: 9.1662 - val_mse: 9.1662
# Epoch 121/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.8691 - mse: 8.8691 - val_loss: 8.9981 - val_mse: 8.9981
# Epoch 122/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.7391 - mse: 8.7391 - val_loss: 9.1226 - val_mse: 9.1226
# Epoch 123/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.7049 - mse: 8.7049 - val_loss: 8.8439 - val_mse: 8.8439
# Epoch 124/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.6860 - mse: 8.6860 - val_loss: 8.9721 - val_mse: 8.9721
# Epoch 125/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.6550 - mse: 8.6550 - val_loss: 9.2128 - val_mse: 9.2128
# Epoch 126/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.7128 - mse: 8.7128 - val_loss: 8.7417 - val_mse: 8.7417
# Epoch 127/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.5573 - mse: 8.5573 - val_loss: 9.2017 - val_mse: 9.2017
# Epoch 128/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.5520 - mse: 8.5520 - val_loss: 8.8717 - val_mse: 8.8717
# Epoch 129/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4646 - mse: 8.4646 - val_loss: 9.0549 - val_mse: 9.0549
# Epoch 130/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.5359 - mse: 8.5359 - val_loss: 8.8155 - val_mse: 8.8155
# Epoch 131/250
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5485 - mse: 8.5485 - val_loss: 8.9261 - val_mse: 8.9261
# Epoch 132/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.5848 - mse: 8.5848 - val_loss: 8.7725 - val_mse: 8.7725
# Epoch 133/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.5788 - mse: 8.5788 - val_loss: 8.8551 - val_mse: 8.8551
# Epoch 134/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.4345 - mse: 8.4345 - val_loss: 8.6612 - val_mse: 8.6612
# Epoch 135/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.3959 - mse: 8.3959 - val_loss: 8.6733 - val_mse: 8.6733
# Epoch 136/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4377 - mse: 8.4377 - val_loss: 8.7436 - val_mse: 8.7436
# Epoch 137/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4571 - mse: 8.4571 - val_loss: 8.6609 - val_mse: 8.6609
# Epoch 138/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.2689 - mse: 8.2689 - val_loss: 8.7065 - val_mse: 8.7065
# Epoch 139/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.2655 - mse: 8.2655 - val_loss: 8.7956 - val_mse: 8.7956
# Epoch 140/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.2495 - mse: 8.2495 - val_loss: 8.6018 - val_mse: 8.6018
# Epoch 141/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.2527 - mse: 8.2527 - val_loss: 8.7274 - val_mse: 8.7274
# Epoch 142/250
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3720 - mse: 8.3720 - val_loss: 8.7142 - val_mse: 8.7142
# Epoch 143/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1902 - mse: 8.1902 - val_loss: 8.7031 - val_mse: 8.7031
# Epoch 144/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.2127 - mse: 8.2127 - val_loss: 8.6362 - val_mse: 8.6362
# Epoch 145/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1577 - mse: 8.1577 - val_loss: 8.6885 - val_mse: 8.6885
# Epoch 146/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1438 - mse: 8.1438 - val_loss: 8.6740 - val_mse: 8.6740
# Epoch 147/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.1242 - mse: 8.1242 - val_loss: 8.3918 - val_mse: 8.3918
# Epoch 148/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.1453 - mse: 8.1453 - val_loss: 8.5530 - val_mse: 8.5530
# Epoch 149/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.0881 - mse: 8.0881 - val_loss: 8.5278 - val_mse: 8.5278
# Epoch 150/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.0550 - mse: 8.0550 - val_loss: 8.6468 - val_mse: 8.6468
# Epoch 151/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.0149 - mse: 8.0149 - val_loss: 8.4353 - val_mse: 8.4353
# Epoch 152/250
# 12/12 [==============================] - 0s 6ms/step - loss: 8.0648 - mse: 8.0648 - val_loss: 8.5261 - val_mse: 8.5261
# Epoch 153/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.9932 - mse: 7.9932 - val_loss: 8.6302 - val_mse: 8.6302
# Epoch 154/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.0056 - mse: 8.0056 - val_loss: 8.3315 - val_mse: 8.3315
# Epoch 155/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.8906 - mse: 7.8906 - val_loss: 8.5567 - val_mse: 8.5567
# Epoch 156/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.9256 - mse: 7.9256 - val_loss: 8.5126 - val_mse: 8.5126
# Epoch 157/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.9261 - mse: 7.9261 - val_loss: 8.4870 - val_mse: 8.4870
# Epoch 158/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.9166 - mse: 7.9166 - val_loss: 8.5060 - val_mse: 8.5060
# Epoch 159/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.9438 - mse: 7.9438 - val_loss: 8.3480 - val_mse: 8.3480
# Epoch 160/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.8954 - mse: 7.8954 - val_loss: 8.4659 - val_mse: 8.4659
# Epoch 161/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.8142 - mse: 7.8142 - val_loss: 8.4649 - val_mse: 8.4649
# Epoch 162/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.8888 - mse: 7.8888 - val_loss: 8.3409 - val_mse: 8.3409
# Epoch 163/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.7809 - mse: 7.7809 - val_loss: 8.3342 - val_mse: 8.3342
# Epoch 164/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.8183 - mse: 7.8183 - val_loss: 8.6353 - val_mse: 8.6353
# Epoch 165/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.7474 - mse: 7.7474 - val_loss: 8.3185 - val_mse: 8.3185
# Epoch 166/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.7401 - mse: 7.7401 - val_loss: 8.5067 - val_mse: 8.5067
# Epoch 167/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.7197 - mse: 7.7197 - val_loss: 8.3606 - val_mse: 8.3606
# Epoch 168/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.6795 - mse: 7.6795 - val_loss: 8.4693 - val_mse: 8.4693
# Epoch 169/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.6603 - mse: 7.6603 - val_loss: 8.1674 - val_mse: 8.1674
# Epoch 170/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.7594 - mse: 7.7594 - val_loss: 8.3848 - val_mse: 8.3848
# Epoch 171/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.9674 - mse: 7.9674 - val_loss: 8.3229 - val_mse: 8.3229
# Epoch 172/250
# 12/12 [==============================] - 0s 8ms/step - loss: 7.6510 - mse: 7.6510 - val_loss: 8.4514 - val_mse: 8.4514
# Epoch 173/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5833 - mse: 7.5833 - val_loss: 8.4207 - val_mse: 8.4207
# Epoch 174/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.6232 - mse: 7.6232 - val_loss: 8.2306 - val_mse: 8.2306
# Epoch 175/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.5493 - mse: 7.5493 - val_loss: 8.2572 - val_mse: 8.2572
# Epoch 176/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.5875 - mse: 7.5875 - val_loss: 8.2756 - val_mse: 8.2756
# Epoch 177/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5487 - mse: 7.5487 - val_loss: 8.0029 - val_mse: 8.0029
# Epoch 178/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.4314 - mse: 7.4314 - val_loss: 8.1576 - val_mse: 8.1576
# Epoch 179/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4731 - mse: 7.4731 - val_loss: 8.1103 - val_mse: 8.1103
# Epoch 180/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.4001 - mse: 7.4001 - val_loss: 8.0899 - val_mse: 8.0899
# Epoch 181/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.4006 - mse: 7.4006 - val_loss: 8.1144 - val_mse: 8.1144
# Epoch 182/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4833 - mse: 7.4833 - val_loss: 8.2147 - val_mse: 8.2147
# Epoch 183/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.4645 - mse: 7.4645 - val_loss: 8.1400 - val_mse: 8.1400
# Epoch 184/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4099 - mse: 7.4099 - val_loss: 8.1778 - val_mse: 8.1778
# Epoch 185/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.4479 - mse: 7.4479 - val_loss: 7.9254 - val_mse: 7.9254
# Epoch 186/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.3856 - mse: 7.3856 - val_loss: 8.1108 - val_mse: 8.1108
# Epoch 187/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3990 - mse: 7.3990 - val_loss: 8.1254 - val_mse: 8.1254
# Epoch 188/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3085 - mse: 7.3085 - val_loss: 7.9408 - val_mse: 7.9408
# Epoch 189/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3862 - mse: 7.3862 - val_loss: 8.1469 - val_mse: 8.1469
# Epoch 190/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.3346 - mse: 7.3346 - val_loss: 7.9029 - val_mse: 7.9029
# Epoch 191/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.2335 - mse: 7.2335 - val_loss: 8.0131 - val_mse: 8.0131
# Epoch 192/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4276 - mse: 7.4276 - val_loss: 7.8327 - val_mse: 7.8327
# Epoch 193/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.2996 - mse: 7.2996 - val_loss: 8.1077 - val_mse: 8.1077
# Epoch 194/250
# 12/12 [==============================] - 0s 10ms/step - loss: 7.2613 - mse: 7.2613 - val_loss: 7.8938 - val_mse: 7.8938
# Epoch 195/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.2720 - mse: 7.2720 - val_loss: 7.9418 - val_mse: 7.9418
# Epoch 196/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1539 - mse: 7.1539 - val_loss: 8.1168 - val_mse: 8.1168
# Epoch 197/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.1640 - mse: 7.1640 - val_loss: 7.9743 - val_mse: 7.9743
# Epoch 198/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.1941 - mse: 7.1941 - val_loss: 7.7675 - val_mse: 7.7675
# Epoch 199/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1679 - mse: 7.1679 - val_loss: 8.0619 - val_mse: 8.0619
# Epoch 200/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1641 - mse: 7.1641 - val_loss: 7.9039 - val_mse: 7.9039
# Epoch 201/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.0882 - mse: 7.0882 - val_loss: 7.9295 - val_mse: 7.9295
# Epoch 202/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.0432 - mse: 7.0432 - val_loss: 7.8650 - val_mse: 7.8650
# Epoch 203/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.1542 - mse: 7.1542 - val_loss: 8.0526 - val_mse: 8.0526
# Epoch 204/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.0560 - mse: 7.0560 - val_loss: 7.8285 - val_mse: 7.8285
# Epoch 205/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1401 - mse: 7.1401 - val_loss: 7.9864 - val_mse: 7.9864
# Epoch 206/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.1235 - mse: 7.1235 - val_loss: 7.7508 - val_mse: 7.7508
# Epoch 207/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1331 - mse: 7.1331 - val_loss: 7.8709 - val_mse: 7.8709
# Epoch 208/250
# 12/12 [==============================] - 0s 6ms/step - loss: 7.0948 - mse: 7.0948 - val_loss: 7.8671 - val_mse: 7.8671
# Epoch 209/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.9486 - mse: 6.9486 - val_loss: 7.8973 - val_mse: 7.8973
# Epoch 210/250
# 12/12 [==============================] - 0s 10ms/step - loss: 7.0093 - mse: 7.0093 - val_loss: 7.8409 - val_mse: 7.8409
# Epoch 211/250
# 12/12 [==============================] - 0s 10ms/step - loss: 7.1790 - mse: 7.1790 - val_loss: 7.7496 - val_mse: 7.7496
# Epoch 212/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9109 - mse: 6.9109 - val_loss: 7.7141 - val_mse: 7.7141
# Epoch 213/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9004 - mse: 6.9004 - val_loss: 7.7671 - val_mse: 7.7671
# Epoch 214/250
# 12/12 [==============================] - 0s 11ms/step - loss: 6.8479 - mse: 6.8479 - val_loss: 7.7943 - val_mse: 7.7943
# Epoch 215/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8229 - mse: 6.8229 - val_loss: 7.8526 - val_mse: 7.8526
# Epoch 216/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.9016 - mse: 6.9016 - val_loss: 7.7901 - val_mse: 7.7901
# Epoch 217/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8985 - mse: 6.8985 - val_loss: 7.6794 - val_mse: 7.6794
# Epoch 218/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8005 - mse: 6.8005 - val_loss: 7.7572 - val_mse: 7.7572
# Epoch 219/250
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8018 - mse: 6.8018 - val_loss: 7.7359 - val_mse: 7.7359
# Epoch 220/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7924 - mse: 6.7924 - val_loss: 7.6241 - val_mse: 7.6241
# Epoch 221/250
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7946 - mse: 6.7946 - val_loss: 7.7477 - val_mse: 7.7477
# Epoch 222/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9374 - mse: 6.9374 - val_loss: 7.9622 - val_mse: 7.9622
# Epoch 223/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.7636 - mse: 6.7636 - val_loss: 7.6404 - val_mse: 7.6404
# Epoch 224/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.7231 - mse: 6.7231 - val_loss: 7.7106 - val_mse: 7.7106
# Epoch 225/250
# 12/12 [==============================] - 0s 12ms/step - loss: 6.8540 - mse: 6.8540 - val_loss: 7.6936 - val_mse: 7.6936
# Epoch 226/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8043 - mse: 6.8043 - val_loss: 7.7143 - val_mse: 7.7143
# Epoch 227/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7977 - mse: 6.7977 - val_loss: 7.4684 - val_mse: 7.4684
# Epoch 228/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8897 - mse: 6.8897 - val_loss: 7.8529 - val_mse: 7.8529
# Epoch 229/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7992 - mse: 6.7992 - val_loss: 7.5314 - val_mse: 7.5314
# Epoch 230/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.7401 - mse: 6.7401 - val_loss: 7.7400 - val_mse: 7.7400
# Epoch 231/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.6165 - mse: 6.6165 - val_loss: 7.6315 - val_mse: 7.6315
# Epoch 232/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5970 - mse: 6.5970 - val_loss: 7.6182 - val_mse: 7.6182
# Epoch 233/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.5528 - mse: 6.5528 - val_loss: 7.5643 - val_mse: 7.5643
# Epoch 234/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.6238 - mse: 6.6238 - val_loss: 7.6423 - val_mse: 7.6423
# Epoch 235/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.5259 - mse: 6.5259 - val_loss: 7.4622 - val_mse: 7.4622
# Epoch 236/250
# 12/12 [==============================] - 0s 8ms/step - loss: 6.5438 - mse: 6.5438 - val_loss: 7.5244 - val_mse: 7.5244
# Epoch 237/250
# 12/12 [==============================] - 0s 5ms/step - loss: 6.5431 - mse: 6.5431 - val_loss: 7.4325 - val_mse: 7.4325
# Epoch 238/250
# 12/12 [==============================] - 0s 5ms/step - loss: 6.4221 - mse: 6.4221 - val_loss: 7.4413 - val_mse: 7.4413
# Epoch 239/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.5277 - mse: 6.5277 - val_loss: 7.5778 - val_mse: 7.5778
# Epoch 240/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.5332 - mse: 6.5332 - val_loss: 7.6982 - val_mse: 7.6982
# Epoch 241/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.4475 - mse: 6.4475 - val_loss: 7.5614 - val_mse: 7.5614
# Epoch 242/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3939 - mse: 6.3939 - val_loss: 7.4476 - val_mse: 7.4476
# Epoch 243/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3528 - mse: 6.3528 - val_loss: 7.4541 - val_mse: 7.4541
# Epoch 244/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3423 - mse: 6.3423 - val_loss: 7.4255 - val_mse: 7.4255
# Epoch 245/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.3391 - mse: 6.3391 - val_loss: 7.3645 - val_mse: 7.3645
# Epoch 246/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3456 - mse: 6.3456 - val_loss: 7.4371 - val_mse: 7.4371
# Epoch 247/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.5014 - mse: 6.5014 - val_loss: 7.6366 - val_mse: 7.6366
# Epoch 248/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3934 - mse: 6.3934 - val_loss: 7.3309 - val_mse: 7.3309
# Epoch 249/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.5816 - mse: 6.5816 - val_loss: 7.6170 - val_mse: 7.6170
# Epoch 250/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.2597 - mse: 6.2597 - val_loss: 7.3119 - val_mse: 7.3119

# %% [markdown]
# ## Question 1
#
# Now that you know how MSE works, you need to plot the behavior of **square** component of MSE loss for the synthetic errors given.

# %% [markdown]
# ### Answer 1

# %%
errors = np.arange(-5, 6)
n = len(errors)
def mse(error):
    return error**2

mse_values = mse(errors)
plt.plot(errors, mse_values, c='#ED4F46', marker='o')
plt.grid()
plt.xlabel('Difference between actual and estimated ouputs')
plt.ylabel('Mean Squared Errors')
plt.show()

# %% [markdown]
# ## Mean Absolute Error [MAE]
#
# Mean absolute error, on the other hand, is measured as the average of sum of absolute differences between predictions and actual observations.
#
# Like MSE, this as well measures the magnitude of error without considering their direction.
#
# Unlike MSE, MAE needs more complicated tools such as linear programming to compute the gradients. Plus MAE is more robust to outliers since it does not make use of square.
#
# Let's assume there are $n$ data samples, for $i^{th}$ sample; the actual output is $y_i$ and $\hat{y}_i$ is the estimated output from the regression model.
#
# We first take the absolute difference between the original and estimated output with $|y_i - \hat{y}_i|2$. Then we take sum of the absolute differences for all the samples. And finally divide it by the total count of samples, which is $n$.
#
# $$MSE = \frac{\sum_{i=1}^{n}|y_i - \hat{y}_i|}{n}$$

# %%
model = keras.Sequential([
        tf.keras.layers.Dense(100, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(50, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(20, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(1)
    ])

model.compile(optimizer='adam',
              loss='mae',
              metrics=['mae'])

model.fit(train_features, train_labels, epochs=250, validation_split = 0.1)

# %% [markdown]
# ## Question 2
#
# Now that you know how MAE works, you need to plot the behavior of the **absolute** component of MAE for the synthetic errors given.

# %% [markdown]
# ### Answer 2

# %%
errors = np.arange(-5, 6)
n = len(errors)

def mae(error):
    return np.abs(error)

mae_values = mae(errors)

plt.plot(errors, mae_values, c='#0095B6', marker='o')
plt.grid()
plt.xlabel('Difference between actual and estimated ouputs')
plt.ylabel('Mean Absolute Errors')
plt.show()

# %% [markdown]
# ## Mean Squared Logarithmic Error [MSLE]
#
# MSLE is just like MSE, but we have to take $log$ of the actual and estimated outputs because squaring and averaging.
#
# The introduction of the logarithm makes MSLE only care about the relative difference between the true and the predicted value, or in other words, it only cares about the percentual difference between them.
#
# This means that MSLE will treat small differences between small true and predicted values approximately the same as big differences between large true and predicted values.
#
# We can use MSLE when we don't want large errors to be significantly more penalized than small ones, in those cases where the range of the target value is large.
#
# *Example*: You want to predict future house prices, and your dataset includes homes that are orders of magnitude different in price. The price is a continuous value, and therefore, we want to do regression. MSLE can here be used as the loss function.
#
# $$MSLE = \frac{\sum_{i=1}^{n}(\log(y_i+1) - \log(\hat{y}_i+1))^2}{n}$$

# %%
model = keras.Sequential([
        tf.keras.layers.Dense(100, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(50, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(20, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(1)
    ])

model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredLogarithmicError(),
              metrics=['mean_squared_logarithmic_error'])

model.fit(train_features, train_labels, epochs=150, validation_split = 0.1)

# %% [markdown]
# ## Question 3
#
# Now that you know how MSLE works, you need to plot the behavior of **squared log** component of MSLE for the synthetic errors given.

# %% [markdown]
# ### Answer 3

# %%
actual_outputs = np.arange(0, 51)
n = len(actual_outputs)
estimated_outputs = np.zeros(n)

def msle(actual, estimated):
    return (1/n) * np.sum((np.log1p(actual) - np.log1p(estimated))**2)

msle_values = np.zeros(n)
for i in range(n):
    msle_values[i] = msle(actual_outputs[i], estimated_outputs[i])

plt.plot(actual_outputs, msle_values, c='#F47789', marker='o')
plt.grid()
plt.xlabel('Actual ouputs')
plt.ylabel('Mean Squared Logarithmic Errors')
plt.show()

# %% [markdown]
# ## Question 4
#
# Why do we add $1$ to the outputs before passing it through $\log()$?

# %% [markdown]
# ### Answer 4
#
# - To prevent taking the logarithm of zero or negative values.

# %% [markdown]
# ## Question 5
#
# Write your observations about MSE, MAE, and MSLE; and compare the results achieved with all 3 loss functions.

# %% [markdown]
# ### Answer 5
#
# 1. MSE: differentiable and sensitive to outliers.
# 2. MAE: treats all errors equally and robust to outliers.
# 3. MSLE: gives more importance to relative errors rather than absolute errors and sensitive to large errors

# %% [markdown]
# ## Question 6
#
# Plug-in any of the loss functions from [TensorFlow](https://www.tensorflow.org/api_docs/python/tf/keras/losses) docs to the `model.compile` method and see if the difference in model performance as compared to MSE, MAE, and MSLE.

# %%
model = keras.Sequential([
        tf.keras.layers.Dense(100, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(50, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(20, activation='relu', input_shape=[len(train_features[0])]),
        tf.keras.layers.Dense(1)
    ])

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])
# model.compile(optimizer='adam',
#               loss='mean_absolute_error',
#               metrics=['mean_absolute_error'])
# model.compile(optimizer='adam',
#               loss='mean_squared_logarithmic_error',
              metrics=['mean_squared_logarithmic_error'])

model.fit(train_features, train_labels, epochs=250, validation_split = 0.1)
# Out:
# Epoch 1/250
# 12/12 [==============================] - 2s 16ms/step - loss: 558.2825 - mean_squared_error: 558.2825 - val_loss: 432.2110 - val_mean_squared_error: 432.2110
# Epoch 2/250
# 12/12 [==============================] - 0s 6ms/step - loss: 460.6300 - mean_squared_error: 460.6300 - val_loss: 314.9033 - val_mean_squared_error: 314.9033
# Epoch 3/250
# 12/12 [==============================] - 0s 6ms/step - loss: 307.4275 - mean_squared_error: 307.4275 - val_loss: 159.5812 - val_mean_squared_error: 159.5812
# Epoch 4/250
# 12/12 [==============================] - 0s 7ms/step - loss: 151.9822 - mean_squared_error: 151.9822 - val_loss: 64.5655 - val_mean_squared_error: 64.5655
# Epoch 5/250
# 12/12 [==============================] - 0s 6ms/step - loss: 87.2947 - mean_squared_error: 87.2947 - val_loss: 52.5778 - val_mean_squared_error: 52.5778
# Epoch 6/250
# 12/12 [==============================] - 0s 6ms/step - loss: 59.1942 - mean_squared_error: 59.1942 - val_loss: 29.3733 - val_mean_squared_error: 29.3733
# Epoch 7/250
# 12/12 [==============================] - 0s 7ms/step - loss: 40.8013 - mean_squared_error: 40.8013 - val_loss: 21.0602 - val_mean_squared_error: 21.0602
# Epoch 8/250
# 12/12 [==============================] - 0s 6ms/step - loss: 30.5279 - mean_squared_error: 30.5279 - val_loss: 21.0524 - val_mean_squared_error: 21.0524
# Epoch 9/250
# 12/12 [==============================] - 0s 6ms/step - loss: 26.7734 - mean_squared_error: 26.7734 - val_loss: 21.2690 - val_mean_squared_error: 21.2690
# Epoch 10/250
# 12/12 [==============================] - 0s 7ms/step - loss: 23.7294 - mean_squared_error: 23.7294 - val_loss: 19.2773 - val_mean_squared_error: 19.2773
# Epoch 11/250
# 12/12 [==============================] - 0s 7ms/step - loss: 21.8787 - mean_squared_error: 21.8787 - val_loss: 19.8009 - val_mean_squared_error: 19.8009
# Epoch 12/250
# 12/12 [==============================] - 0s 6ms/step - loss: 20.4016 - mean_squared_error: 20.4016 - val_loss: 19.1894 - val_mean_squared_error: 19.1894
# Epoch 13/250
# 12/12 [==============================] - 0s 7ms/step - loss: 19.3258 - mean_squared_error: 19.3258 - val_loss: 18.5690 - val_mean_squared_error: 18.5690
# Epoch 14/250
# 12/12 [==============================] - 0s 5ms/step - loss: 18.0842 - mean_squared_error: 18.0842 - val_loss: 17.7692 - val_mean_squared_error: 17.7692
# Epoch 15/250
# 12/12 [==============================] - 0s 6ms/step - loss: 17.0438 - mean_squared_error: 17.0438 - val_loss: 17.6308 - val_mean_squared_error: 17.6308
# Epoch 16/250
# 12/12 [==============================] - 0s 5ms/step - loss: 16.3977 - mean_squared_error: 16.3977 - val_loss: 16.6807 - val_mean_squared_error: 16.6807
# Epoch 17/250
# 12/12 [==============================] - 0s 7ms/step - loss: 15.8072 - mean_squared_error: 15.8072 - val_loss: 16.5655 - val_mean_squared_error: 16.5655
# Epoch 18/250
# 12/12 [==============================] - 0s 8ms/step - loss: 15.0210 - mean_squared_error: 15.0210 - val_loss: 15.9958 - val_mean_squared_error: 15.9958
# Epoch 19/250
# 12/12 [==============================] - 0s 6ms/step - loss: 14.5222 - mean_squared_error: 14.5222 - val_loss: 15.6996 - val_mean_squared_error: 15.6996
# Epoch 20/250
# 12/12 [==============================] - 0s 7ms/step - loss: 13.8498 - mean_squared_error: 13.8498 - val_loss: 14.5126 - val_mean_squared_error: 14.5126
# Epoch 21/250
# 12/12 [==============================] - 0s 6ms/step - loss: 13.5098 - mean_squared_error: 13.5098 - val_loss: 13.5496 - val_mean_squared_error: 13.5496
# Epoch 22/250
# 12/12 [==============================] - 0s 6ms/step - loss: 13.2354 - mean_squared_error: 13.2354 - val_loss: 13.1233 - val_mean_squared_error: 13.1233
# Epoch 23/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.5863 - mean_squared_error: 12.5863 - val_loss: 13.1641 - val_mean_squared_error: 13.1641
# Epoch 24/250
# 12/12 [==============================] - 0s 7ms/step - loss: 12.4731 - mean_squared_error: 12.4731 - val_loss: 12.4109 - val_mean_squared_error: 12.4109
# Epoch 25/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.9556 - mean_squared_error: 11.9556 - val_loss: 12.0856 - val_mean_squared_error: 12.0856
# Epoch 26/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.7115 - mean_squared_error: 11.7115 - val_loss: 12.2919 - val_mean_squared_error: 12.2919
# Epoch 27/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.5470 - mean_squared_error: 11.5470 - val_loss: 11.1965 - val_mean_squared_error: 11.1965
# Epoch 28/250
# 12/12 [==============================] - 0s 7ms/step - loss: 11.5432 - mean_squared_error: 11.5432 - val_loss: 12.3286 - val_mean_squared_error: 12.3286
# Epoch 29/250
# 12/12 [==============================] - 0s 7ms/step - loss: 10.9275 - mean_squared_error: 10.9275 - val_loss: 11.5696 - val_mean_squared_error: 11.5696
# Epoch 30/250
# 12/12 [==============================] - 0s 7ms/step - loss: 10.8792 - mean_squared_error: 10.8792 - val_loss: 11.0420 - val_mean_squared_error: 11.0420
# Epoch 31/250
# 12/12 [==============================] - 0s 6ms/step - loss: 10.5597 - mean_squared_error: 10.5597 - val_loss: 10.7774 - val_mean_squared_error: 10.7774
# Epoch 32/250
# 12/12 [==============================] - 0s 6ms/step - loss: 10.3789 - mean_squared_error: 10.3789 - val_loss: 10.3229 - val_mean_squared_error: 10.3229
# Epoch 33/250
# 12/12 [==============================] - 0s 8ms/step - loss: 10.1555 - mean_squared_error: 10.1555 - val_loss: 10.4643 - val_mean_squared_error: 10.4643
# Epoch 34/250
# 12/12 [==============================] - 0s 7ms/step - loss: 10.2188 - mean_squared_error: 10.2188 - val_loss: 10.1617 - val_mean_squared_error: 10.1617
# Epoch 35/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9845 - mean_squared_error: 9.9845 - val_loss: 10.1645 - val_mean_squared_error: 10.1645
# Epoch 36/250
# 12/12 [==============================] - 0s 6ms/step - loss: 10.2271 - mean_squared_error: 10.2271 - val_loss: 9.4903 - val_mean_squared_error: 9.4903
# Epoch 37/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.8381 - mean_squared_error: 9.8381 - val_loss: 9.5187 - val_mean_squared_error: 9.5187
# Epoch 38/250
# 12/12 [==============================] - 0s 7ms/step - loss: 9.5969 - mean_squared_error: 9.5969 - val_loss: 9.3491 - val_mean_squared_error: 9.3491
# Epoch 39/250
# 12/12 [==============================] - 0s 13ms/step - loss: 9.4005 - mean_squared_error: 9.4005 - val_loss: 8.9985 - val_mean_squared_error: 8.9985
# Epoch 40/250
# 12/12 [==============================] - 0s 18ms/step - loss: 9.2813 - mean_squared_error: 9.2813 - val_loss: 9.1877 - val_mean_squared_error: 9.1877
# Epoch 41/250
# 12/12 [==============================] - 0s 8ms/step - loss: 9.0846 - mean_squared_error: 9.0846 - val_loss: 8.7782 - val_mean_squared_error: 8.7782
# Epoch 42/250
# 12/12 [==============================] - 0s 6ms/step - loss: 9.0565 - mean_squared_error: 9.0565 - val_loss: 8.7865 - val_mean_squared_error: 8.7865
# Epoch 43/250
# 12/12 [==============================] - 0s 5ms/step - loss: 8.9684 - mean_squared_error: 8.9684 - val_loss: 9.0425 - val_mean_squared_error: 9.0425
# Epoch 44/250
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8754 - mean_squared_error: 8.8754 - val_loss: 8.6297 - val_mean_squared_error: 8.6297
# Epoch 45/250
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8075 - mean_squared_error: 8.8075 - val_loss: 8.0549 - val_mean_squared_error: 8.0549
# Epoch 46/250
# 12/12 [==============================] - 0s 16ms/step - loss: 8.5587 - mean_squared_error: 8.5587 - val_loss: 7.8859 - val_mean_squared_error: 7.8859
# Epoch 47/250
# 12/12 [==============================] - 0s 12ms/step - loss: 8.5737 - mean_squared_error: 8.5737 - val_loss: 8.1495 - val_mean_squared_error: 8.1495
# Epoch 48/250
# 12/12 [==============================] - 0s 14ms/step - loss: 8.7221 - mean_squared_error: 8.7221 - val_loss: 8.0363 - val_mean_squared_error: 8.0363
# Epoch 49/250
# 12/12 [==============================] - 0s 14ms/step - loss: 8.3984 - mean_squared_error: 8.3984 - val_loss: 7.8739 - val_mean_squared_error: 7.8739
# Epoch 50/250
# 12/12 [==============================] - 0s 16ms/step - loss: 8.2555 - mean_squared_error: 8.2555 - val_loss: 7.8879 - val_mean_squared_error: 7.8879
# Epoch 51/250
# 12/12 [==============================] - 0s 22ms/step - loss: 8.3422 - mean_squared_error: 8.3422 - val_loss: 8.3209 - val_mean_squared_error: 8.3209
# Epoch 52/250
# 12/12 [==============================] - 0s 15ms/step - loss: 8.0938 - mean_squared_error: 8.0938 - val_loss: 8.2880 - val_mean_squared_error: 8.2880
# Epoch 53/250
# 12/12 [==============================] - 0s 9ms/step - loss: 7.9965 - mean_squared_error: 7.9965 - val_loss: 7.6244 - val_mean_squared_error: 7.6244
# Epoch 54/250
# 12/12 [==============================] - 0s 8ms/step - loss: 7.9335 - mean_squared_error: 7.9335 - val_loss: 7.4230 - val_mean_squared_error: 7.4230
# Epoch 55/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.9890 - mean_squared_error: 7.9890 - val_loss: 7.6291 - val_mean_squared_error: 7.6291
# Epoch 56/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.7952 - mean_squared_error: 7.7952 - val_loss: 7.9680 - val_mean_squared_error: 7.9680
# Epoch 57/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.6375 - mean_squared_error: 7.6375 - val_loss: 7.9919 - val_mean_squared_error: 7.9919
# Epoch 58/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.5355 - mean_squared_error: 7.5355 - val_loss: 7.6455 - val_mean_squared_error: 7.6455
# Epoch 59/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3943 - mean_squared_error: 7.3943 - val_loss: 7.0594 - val_mean_squared_error: 7.0594
# Epoch 60/250
# 12/12 [==============================] - 0s 5ms/step - loss: 7.2932 - mean_squared_error: 7.2932 - val_loss: 7.2144 - val_mean_squared_error: 7.2144
# Epoch 61/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1439 - mean_squared_error: 7.1439 - val_loss: 7.2372 - val_mean_squared_error: 7.2372
# Epoch 62/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1792 - mean_squared_error: 7.1792 - val_loss: 6.6499 - val_mean_squared_error: 6.6499
# Epoch 63/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.9867 - mean_squared_error: 6.9867 - val_loss: 6.4989 - val_mean_squared_error: 6.4989
# Epoch 64/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.0606 - mean_squared_error: 7.0606 - val_loss: 7.0746 - val_mean_squared_error: 7.0746
# Epoch 65/250
# 12/12 [==============================] - 0s 7ms/step - loss: 7.0147 - mean_squared_error: 7.0147 - val_loss: 6.6622 - val_mean_squared_error: 6.6622
# Epoch 66/250
# 12/12 [==============================] - 0s 6ms/step - loss: 6.9551 - mean_squared_error: 6.9551 - val_loss: 6.9052 - val_mean_squared_error: 6.9052
# Epoch 67/250
# 12/12 [==============================] - 0s 5ms/step - loss: 6.8150 - mean_squared_error: 6.8150 - val_loss: 6.6175 - val_mean_squared_error: 6.6175
# Epoch 68/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.7201 - mean_squared_error: 6.7201 - val_loss: 6.6348 - val_mean_squared_error: 6.6348
# Epoch 69/250
# 12/12 [==============================] - 0s 5ms/step - loss: 6.6408 - mean_squared_error: 6.6408 - val_loss: 6.6392 - val_mean_squared_error: 6.6392
# Epoch 70/250
# 12/12 [==============================] - 0s 7ms/step - loss: 6.7482 - mean_squared_error: 6.7482 - val_loss: 6.4729 - val_mean_squared_error: 6.4729
# Epoch 71/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.5603 - mean_squared_error: 6.5603 - val_loss: 6.4565 - val_mean_squared_error: 6.4565
# Epoch 72/250
# 12/12 [==============================] - 0s 11ms/step - loss: 6.4726 - mean_squared_error: 6.4726 - val_loss: 6.8741 - val_mean_squared_error: 6.8741
# Epoch 73/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.5761 - mean_squared_error: 6.5761 - val_loss: 6.4538 - val_mean_squared_error: 6.4538
# Epoch 74/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.6180 - mean_squared_error: 6.6180 - val_loss: 6.4840 - val_mean_squared_error: 6.4840
# Epoch 75/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.3944 - mean_squared_error: 6.3944 - val_loss: 6.6127 - val_mean_squared_error: 6.6127
# Epoch 76/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.2372 - mean_squared_error: 6.2372 - val_loss: 6.1585 - val_mean_squared_error: 6.1585
# Epoch 77/250
# 12/12 [==============================] - 0s 8ms/step - loss: 6.0082 - mean_squared_error: 6.0082 - val_loss: 6.4216 - val_mean_squared_error: 6.4216
# Epoch 78/250
# 12/12 [==============================] - 0s 10ms/step - loss: 6.1014 - mean_squared_error: 6.1014 - val_loss: 6.3294 - val_mean_squared_error: 6.3294
# Epoch 79/250
# 12/12 [==============================] - 0s 10ms/step - loss: 5.9901 - mean_squared_error: 5.9901 - val_loss: 6.3305 - val_mean_squared_error: 6.3305
# Epoch 80/250
# 12/12 [==============================] - 0s 10ms/step - loss: 5.9421 - mean_squared_error: 5.9421 - val_loss: 5.9936 - val_mean_squared_error: 5.9936
# Epoch 81/250
# 12/12 [==============================] - 0s 9ms/step - loss: 6.0299 - mean_squared_error: 6.0299 - val_loss: 6.5374 - val_mean_squared_error: 6.5374
# Epoch 82/250
# 12/12 [==============================] - 0s 10ms/step - loss: 5.7620 - mean_squared_error: 5.7620 - val_loss: 6.0126 - val_mean_squared_error: 6.0126
# Epoch 83/250
# 12/12 [==============================] - 0s 8ms/step - loss: 5.7715 - mean_squared_error: 5.7715 - val_loss: 6.1742 - val_mean_squared_error: 6.1742
# Epoch 84/250
# 12/12 [==============================] - 0s 9ms/step - loss: 5.5476 - mean_squared_error: 5.5476 - val_loss: 6.1170 - val_mean_squared_error: 6.1170
# Epoch 85/250
# 12/12 [==============================] - 0s 11ms/step - loss: 5.5297 - mean_squared_error: 5.5297 - val_loss: 6.0473 - val_mean_squared_error: 6.0473
# Epoch 86/250
# 12/12 [==============================] - 0s 8ms/step - loss: 5.6316 - mean_squared_error: 5.6316 - val_loss: 6.2481 - val_mean_squared_error: 6.2481
# Epoch 87/250
# 12/12 [==============================] - 0s 8ms/step - loss: 5.4378 - mean_squared_error: 5.4378 - val_loss: 5.9186 - val_mean_squared_error: 5.9186
# Epoch 88/250
# 12/12 [==============================] - 0s 10ms/step - loss: 5.4092 - mean_squared_error: 5.4092 - val_loss: 6.2933 - val_mean_squared_error: 6.2933
# Epoch 89/250
# 12/12 [==============================] - 0s 8ms/step - loss: 5.5387 - mean_squared_error: 5.5387 - val_loss: 5.8998 - val_mean_squared_error: 5.8998
# Epoch 90/250
# 12/12 [==============================] - 0s 6ms/step - loss: 5.1789 - mean_squared_error: 5.1789 - val_loss: 6.4267 - val_mean_squared_error: 6.4267
# Epoch 91/250
# 12/12 [==============================] - 0s 6ms/step - loss: 5.2798 - mean_squared_error: 5.2798 - val_loss: 5.8864 - val_mean_squared_error: 5.8864
# Epoch 92/250
# 12/12 [==============================] - 0s 6ms/step - loss: 5.2861 - mean_squared_error: 5.2861 - val_loss: 5.6947 - val_mean_squared_error: 5.6947
# Epoch 93/250
# 12/12 [==============================] - 0s 7ms/step - loss: 5.2608 - mean_squared_error: 5.2608 - val_loss: 6.3760 - val_mean_squared_error: 6.3760
# Epoch 94/250
# 12/12 [==============================] - 0s 9ms/step - loss: 5.0695 - mean_squared_error: 5.0695 - val_loss: 5.7969 - val_mean_squared_error: 5.7969
# Epoch 95/250
# 12/12 [==============================] - 0s 9ms/step - loss: 5.1645 - mean_squared_error: 5.1645 - val_loss: 6.1463 - val_mean_squared_error: 6.1463
# Epoch 96/250
# 12/12 [==============================] - 0s 9ms/step - loss: 5.2913 - mean_squared_error: 5.2913 - val_loss: 5.5766 - val_mean_squared_error: 5.5766
# Epoch 97/250
# 12/12 [==============================] - 0s 10ms/step - loss: 5.0609 - mean_squared_error: 5.0609 - val_loss: 6.4780 - val_mean_squared_error: 6.4780
# Epoch 98/250
# 12/12 [==============================] - 0s 17ms/step - loss: 4.9519 - mean_squared_error: 4.9519 - val_loss: 5.8139 - val_mean_squared_error: 5.8139
# Epoch 99/250
# 12/12 [==============================] - 0s 20ms/step - loss: 5.0465 - mean_squared_error: 5.0465 - val_loss: 6.3714 - val_mean_squared_error: 6.3714
# Epoch 100/250
# 12/12 [==============================] - 0s 15ms/step - loss: 4.7992 - mean_squared_error: 4.7992 - val_loss: 5.2654 - val_mean_squared_error: 5.2654
# Epoch 101/250
# 12/12 [==============================] - 0s 22ms/step - loss: 4.6781 - mean_squared_error: 4.6781 - val_loss: 5.7907 - val_mean_squared_error: 5.7907
# Epoch 102/250
# 12/12 [==============================] - 0s 23ms/step - loss: 4.6570 - mean_squared_error: 4.6570 - val_loss: 5.5079 - val_mean_squared_error: 5.5079
# Epoch 103/250
# 12/12 [==============================] - 0s 27ms/step - loss: 4.8602 - mean_squared_error: 4.8602 - val_loss: 6.3337 - val_mean_squared_error: 6.3337
# Epoch 104/250
# 12/12 [==============================] - 0s 18ms/step - loss: 4.8304 - mean_squared_error: 4.8304 - val_loss: 5.2781 - val_mean_squared_error: 5.2781
# Epoch 105/250
# 12/12 [==============================] - 0s 14ms/step - loss: 4.6627 - mean_squared_error: 4.6627 - val_loss: 6.1726 - val_mean_squared_error: 6.1726
# Epoch 106/250
# 12/12 [==============================] - 0s 26ms/step - loss: 4.4338 - mean_squared_error: 4.4338 - val_loss: 5.2129 - val_mean_squared_error: 5.2129
# Epoch 107/250
# 12/12 [==============================] - 0s 25ms/step - loss: 4.6332 - mean_squared_error: 4.6332 - val_loss: 5.9144 - val_mean_squared_error: 5.9144
# Epoch 108/250
# 12/12 [==============================] - 0s 6ms/step - loss: 4.4008 - mean_squared_error: 4.4008 - val_loss: 5.8426 - val_mean_squared_error: 5.8426
# Epoch 109/250
# 12/12 [==============================] - 0s 7ms/step - loss: 4.4127 - mean_squared_error: 4.4127 - val_loss: 5.7071 - val_mean_squared_error: 5.7071
# Epoch 110/250
# 12/12 [==============================] - 0s 8ms/step - loss: 4.3888 - mean_squared_error: 4.3888 - val_loss: 5.8212 - val_mean_squared_error: 5.8212
# Epoch 111/250
# 12/12 [==============================] - 0s 13ms/step - loss: 4.3258 - mean_squared_error: 4.3258 - val_loss: 5.3073 - val_mean_squared_error: 5.3073
# Epoch 112/250
# 12/12 [==============================] - 0s 11ms/step - loss: 4.5295 - mean_squared_error: 4.5295 - val_loss: 6.1316 - val_mean_squared_error: 6.1316
# Epoch 113/250
# 12/12 [==============================] - 0s 12ms/step - loss: 4.3481 - mean_squared_error: 4.3481 - val_loss: 6.0265 - val_mean_squared_error: 6.0265
# Epoch 114/250
# 12/12 [==============================] - 0s 17ms/step - loss: 4.2350 - mean_squared_error: 4.2350 - val_loss: 5.4649 - val_mean_squared_error: 5.4649
# Epoch 115/250
# 12/12 [==============================] - 0s 12ms/step - loss: 4.0842 - mean_squared_error: 4.0842 - val_loss: 5.4311 - val_mean_squared_error: 5.4311
# Epoch 116/250
# 12/12 [==============================] - 0s 14ms/step - loss: 4.1258 - mean_squared_error: 4.1258 - val_loss: 5.6557 - val_mean_squared_error: 5.6557
# Epoch 117/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.9818 - mean_squared_error: 3.9818 - val_loss: 5.5840 - val_mean_squared_error: 5.5840
# Epoch 118/250
# 12/12 [==============================] - 0s 8ms/step - loss: 3.9287 - mean_squared_error: 3.9287 - val_loss: 5.7903 - val_mean_squared_error: 5.7903
# Epoch 119/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.9889 - mean_squared_error: 3.9889 - val_loss: 5.4487 - val_mean_squared_error: 5.4487
# Epoch 120/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.7538 - mean_squared_error: 3.7538 - val_loss: 5.7538 - val_mean_squared_error: 5.7538
# Epoch 121/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.9333 - mean_squared_error: 3.9333 - val_loss: 5.9187 - val_mean_squared_error: 5.9187
# Epoch 122/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.7871 - mean_squared_error: 3.7871 - val_loss: 5.2399 - val_mean_squared_error: 5.2399
# Epoch 123/250
# 12/12 [==============================] - 0s 8ms/step - loss: 3.7400 - mean_squared_error: 3.7400 - val_loss: 6.1647 - val_mean_squared_error: 6.1647
# Epoch 124/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.8596 - mean_squared_error: 3.8596 - val_loss: 5.9162 - val_mean_squared_error: 5.9162
# Epoch 125/250
# 12/12 [==============================] - 0s 7ms/step - loss: 4.1774 - mean_squared_error: 4.1774 - val_loss: 6.5795 - val_mean_squared_error: 6.5795
# Epoch 126/250
# 12/12 [==============================] - 0s 6ms/step - loss: 4.4395 - mean_squared_error: 4.4395 - val_loss: 6.2610 - val_mean_squared_error: 6.2610
# Epoch 127/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8704 - mean_squared_error: 3.8704 - val_loss: 5.5630 - val_mean_squared_error: 5.5630
# Epoch 128/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.7602 - mean_squared_error: 3.7602 - val_loss: 5.7780 - val_mean_squared_error: 5.7780
# Epoch 129/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.8333 - mean_squared_error: 3.8333 - val_loss: 5.3768 - val_mean_squared_error: 5.3768
# Epoch 130/250
# 12/12 [==============================] - 0s 8ms/step - loss: 3.5732 - mean_squared_error: 3.5732 - val_loss: 5.8752 - val_mean_squared_error: 5.8752
# Epoch 131/250
# 12/12 [==============================] - 0s 8ms/step - loss: 3.5005 - mean_squared_error: 3.5005 - val_loss: 5.7120 - val_mean_squared_error: 5.7120
# Epoch 132/250
# 12/12 [==============================] - 0s 5ms/step - loss: 3.7140 - mean_squared_error: 3.7140 - val_loss: 5.4704 - val_mean_squared_error: 5.4704
# Epoch 133/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5032 - mean_squared_error: 3.5032 - val_loss: 5.7608 - val_mean_squared_error: 5.7608
# Epoch 134/250
# 12/12 [==============================] - 0s 8ms/step - loss: 3.3610 - mean_squared_error: 3.3610 - val_loss: 5.1928 - val_mean_squared_error: 5.1928
# Epoch 135/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5785 - mean_squared_error: 3.5785 - val_loss: 5.6426 - val_mean_squared_error: 5.6426
# Epoch 136/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.3457 - mean_squared_error: 3.3457 - val_loss: 5.6468 - val_mean_squared_error: 5.6468
# Epoch 137/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4411 - mean_squared_error: 3.4411 - val_loss: 5.2857 - val_mean_squared_error: 5.2857
# Epoch 138/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.7237 - mean_squared_error: 3.7237 - val_loss: 5.2485 - val_mean_squared_error: 5.2485
# Epoch 139/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.5503 - mean_squared_error: 3.5503 - val_loss: 5.9148 - val_mean_squared_error: 5.9148
# Epoch 140/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.4336 - mean_squared_error: 3.4336 - val_loss: 5.5954 - val_mean_squared_error: 5.5954
# Epoch 141/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3130 - mean_squared_error: 3.3130 - val_loss: 5.3650 - val_mean_squared_error: 5.3650
# Epoch 142/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5380 - mean_squared_error: 3.5380 - val_loss: 5.3345 - val_mean_squared_error: 5.3345
# Epoch 143/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.3161 - mean_squared_error: 3.3161 - val_loss: 5.1543 - val_mean_squared_error: 5.1543
# Epoch 144/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1118 - mean_squared_error: 3.1118 - val_loss: 5.5692 - val_mean_squared_error: 5.5692
# Epoch 145/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.2516 - mean_squared_error: 3.2516 - val_loss: 5.4870 - val_mean_squared_error: 5.4870
# Epoch 146/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.1684 - mean_squared_error: 3.1684 - val_loss: 5.2375 - val_mean_squared_error: 5.2375
# Epoch 147/250
# 12/12 [==============================] - 0s 5ms/step - loss: 3.1991 - mean_squared_error: 3.1991 - val_loss: 5.3455 - val_mean_squared_error: 5.3455
# Epoch 148/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.1842 - mean_squared_error: 3.1842 - val_loss: 5.6281 - val_mean_squared_error: 5.6281
# Epoch 149/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0953 - mean_squared_error: 3.0953 - val_loss: 5.6470 - val_mean_squared_error: 5.6470
# Epoch 150/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0028 - mean_squared_error: 3.0028 - val_loss: 5.3889 - val_mean_squared_error: 5.3889
# Epoch 151/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1027 - mean_squared_error: 3.1027 - val_loss: 5.5589 - val_mean_squared_error: 5.5589
# Epoch 152/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9337 - mean_squared_error: 2.9337 - val_loss: 5.5745 - val_mean_squared_error: 5.5745
# Epoch 153/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8957 - mean_squared_error: 2.8957 - val_loss: 5.2103 - val_mean_squared_error: 5.2103
# Epoch 154/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0580 - mean_squared_error: 3.0580 - val_loss: 6.3547 - val_mean_squared_error: 6.3547
# Epoch 155/250
# 12/12 [==============================] - 0s 6ms/step - loss: 3.1694 - mean_squared_error: 3.1694 - val_loss: 5.3912 - val_mean_squared_error: 5.3912
# Epoch 156/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.8904 - mean_squared_error: 2.8904 - val_loss: 5.2273 - val_mean_squared_error: 5.2273
# Epoch 157/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9874 - mean_squared_error: 2.9874 - val_loss: 5.9568 - val_mean_squared_error: 5.9568
# Epoch 158/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9456 - mean_squared_error: 2.9456 - val_loss: 5.3879 - val_mean_squared_error: 5.3879
# Epoch 159/250
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8023 - mean_squared_error: 2.8023 - val_loss: 5.5291 - val_mean_squared_error: 5.5291
# Epoch 160/250
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0491 - mean_squared_error: 3.0491 - val_loss: 4.9706 - val_mean_squared_error: 4.9706
# Epoch 161/250
# 12/12 [==============================] - 0s 5ms/step - loss: 2.9895 - mean_squared_error: 2.9895 - val_loss: 5.6820 - val_mean_squared_error: 5.6820
# Epoch 162/250
# 12/12 [==============================] - 0s 5ms/step - loss: 2.7524 - mean_squared_error: 2.7524 - val_loss: 5.7369 - val_mean_squared_error: 5.7369
# Epoch 163/250
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8308 - mean_squared_error: 2.8308 - val_loss: 5.7228 - val_mean_squared_error: 5.7228
# Epoch 164/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.7526 - mean_squared_error: 2.7526 - val_loss: 5.7658 - val_mean_squared_error: 5.7658
# Epoch 165/250
# 12/12 [==============================] - 0s 13ms/step - loss: 2.8205 - mean_squared_error: 2.8205 - val_loss: 5.2888 - val_mean_squared_error: 5.2888
# Epoch 166/250
# 12/12 [==============================] - 0s 12ms/step - loss: 2.7739 - mean_squared_error: 2.7739 - val_loss: 5.9363 - val_mean_squared_error: 5.9363
# Epoch 167/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9357 - mean_squared_error: 2.9357 - val_loss: 5.8847 - val_mean_squared_error: 5.8847
# Epoch 168/250
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7530 - mean_squared_error: 2.7530 - val_loss: 5.0964 - val_mean_squared_error: 5.0964
# Epoch 169/250
# 12/12 [==============================] - 0s 13ms/step - loss: 2.9397 - mean_squared_error: 2.9397 - val_loss: 5.7118 - val_mean_squared_error: 5.7118
# Epoch 170/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.7473 - mean_squared_error: 2.7473 - val_loss: 6.1456 - val_mean_squared_error: 6.1456
# Epoch 171/250
# 12/12 [==============================] - 0s 14ms/step - loss: 2.7273 - mean_squared_error: 2.7273 - val_loss: 5.3387 - val_mean_squared_error: 5.3387
# Epoch 172/250
# 12/12 [==============================] - 0s 12ms/step - loss: 2.6220 - mean_squared_error: 2.6220 - val_loss: 5.3571 - val_mean_squared_error: 5.3571
# Epoch 173/250
# 12/12 [==============================] - 0s 18ms/step - loss: 2.7008 - mean_squared_error: 2.7008 - val_loss: 5.5516 - val_mean_squared_error: 5.5516
# Epoch 174/250
# 12/12 [==============================] - 0s 16ms/step - loss: 2.6154 - mean_squared_error: 2.6154 - val_loss: 5.3815 - val_mean_squared_error: 5.3815
# Epoch 175/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5616 - mean_squared_error: 2.5616 - val_loss: 5.5770 - val_mean_squared_error: 5.5770
# Epoch 176/250
# 12/12 [==============================] - 0s 5ms/step - loss: 2.7080 - mean_squared_error: 2.7080 - val_loss: 5.9358 - val_mean_squared_error: 5.9358
# Epoch 177/250
# 12/12 [==============================] - 0s 5ms/step - loss: 2.5889 - mean_squared_error: 2.5889 - val_loss: 5.2472 - val_mean_squared_error: 5.2472
# Epoch 178/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6570 - mean_squared_error: 2.6570 - val_loss: 6.0469 - val_mean_squared_error: 6.0469
# Epoch 179/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5075 - mean_squared_error: 2.5075 - val_loss: 5.3780 - val_mean_squared_error: 5.3780
# Epoch 180/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5858 - mean_squared_error: 2.5858 - val_loss: 5.9425 - val_mean_squared_error: 5.9425
# Epoch 181/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4224 - mean_squared_error: 2.4224 - val_loss: 5.7082 - val_mean_squared_error: 5.7082
# Epoch 182/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4714 - mean_squared_error: 2.4714 - val_loss: 5.2435 - val_mean_squared_error: 5.2435
# Epoch 183/250
# 12/12 [==============================] - 0s 8ms/step - loss: 2.6966 - mean_squared_error: 2.6966 - val_loss: 6.2062 - val_mean_squared_error: 6.2062
# Epoch 184/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4671 - mean_squared_error: 2.4671 - val_loss: 5.6406 - val_mean_squared_error: 5.6406
# Epoch 185/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3818 - mean_squared_error: 2.3818 - val_loss: 5.5356 - val_mean_squared_error: 5.5356
# Epoch 186/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4341 - mean_squared_error: 2.4341 - val_loss: 5.1851 - val_mean_squared_error: 5.1851
# Epoch 187/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5013 - mean_squared_error: 2.5013 - val_loss: 5.2627 - val_mean_squared_error: 5.2627
# Epoch 188/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4839 - mean_squared_error: 2.4839 - val_loss: 5.3565 - val_mean_squared_error: 5.3565
# Epoch 189/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3723 - mean_squared_error: 2.3723 - val_loss: 6.0821 - val_mean_squared_error: 6.0821
# Epoch 190/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4100 - mean_squared_error: 2.4100 - val_loss: 5.2635 - val_mean_squared_error: 5.2635
# Epoch 191/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5958 - mean_squared_error: 2.5958 - val_loss: 6.5379 - val_mean_squared_error: 6.5379
# Epoch 192/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4575 - mean_squared_error: 2.4575 - val_loss: 6.1161 - val_mean_squared_error: 6.1161
# Epoch 193/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4041 - mean_squared_error: 2.4041 - val_loss: 5.1317 - val_mean_squared_error: 5.1317
# Epoch 194/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2918 - mean_squared_error: 2.2918 - val_loss: 5.7507 - val_mean_squared_error: 5.7507
# Epoch 195/250
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3003 - mean_squared_error: 2.3003 - val_loss: 5.5463 - val_mean_squared_error: 5.5463
# Epoch 196/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3019 - mean_squared_error: 2.3019 - val_loss: 5.5495 - val_mean_squared_error: 5.5495
# Epoch 197/250
# 12/12 [==============================] - 0s 13ms/step - loss: 2.2460 - mean_squared_error: 2.2460 - val_loss: 5.5883 - val_mean_squared_error: 5.5883
# Epoch 198/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.3294 - mean_squared_error: 2.3294 - val_loss: 5.3879 - val_mean_squared_error: 5.3879
# Epoch 199/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.1752 - mean_squared_error: 2.1752 - val_loss: 5.4656 - val_mean_squared_error: 5.4656
# Epoch 200/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.3317 - mean_squared_error: 2.3317 - val_loss: 5.4472 - val_mean_squared_error: 5.4472
# Epoch 201/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1664 - mean_squared_error: 2.1664 - val_loss: 5.4847 - val_mean_squared_error: 5.4847
# Epoch 202/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3824 - mean_squared_error: 2.3824 - val_loss: 5.7382 - val_mean_squared_error: 5.7382
# Epoch 203/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3145 - mean_squared_error: 2.3145 - val_loss: 6.2808 - val_mean_squared_error: 6.2808
# Epoch 204/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4249 - mean_squared_error: 2.4249 - val_loss: 5.4635 - val_mean_squared_error: 5.4635
# Epoch 205/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6418 - mean_squared_error: 2.6418 - val_loss: 5.1065 - val_mean_squared_error: 5.1065
# Epoch 206/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.1977 - mean_squared_error: 2.1977 - val_loss: 5.1882 - val_mean_squared_error: 5.1882
# Epoch 207/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.1728 - mean_squared_error: 2.1728 - val_loss: 5.7708 - val_mean_squared_error: 5.7708
# Epoch 208/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.1716 - mean_squared_error: 2.1716 - val_loss: 5.5477 - val_mean_squared_error: 5.5477
# Epoch 209/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.1784 - mean_squared_error: 2.1784 - val_loss: 5.6029 - val_mean_squared_error: 5.6029
# Epoch 210/250
# 12/12 [==============================] - 0s 8ms/step - loss: 2.1122 - mean_squared_error: 2.1122 - val_loss: 5.2193 - val_mean_squared_error: 5.2193
# Epoch 211/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.0768 - mean_squared_error: 2.0768 - val_loss: 5.2522 - val_mean_squared_error: 5.2522
# Epoch 212/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.2488 - mean_squared_error: 2.2488 - val_loss: 5.2581 - val_mean_squared_error: 5.2581
# Epoch 213/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.0664 - mean_squared_error: 2.0664 - val_loss: 5.3081 - val_mean_squared_error: 5.3081
# Epoch 214/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.2430 - mean_squared_error: 2.2430 - val_loss: 5.1756 - val_mean_squared_error: 5.1756
# Epoch 215/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3155 - mean_squared_error: 2.3155 - val_loss: 5.6363 - val_mean_squared_error: 5.6363
# Epoch 216/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.1235 - mean_squared_error: 2.1235 - val_loss: 4.8235 - val_mean_squared_error: 4.8235
# Epoch 217/250
# 12/12 [==============================] - 0s 9ms/step - loss: 2.1034 - mean_squared_error: 2.1034 - val_loss: 5.1774 - val_mean_squared_error: 5.1774
# Epoch 218/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.2511 - mean_squared_error: 2.2511 - val_loss: 5.6833 - val_mean_squared_error: 5.6833
# Epoch 219/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0893 - mean_squared_error: 2.0893 - val_loss: 5.5781 - val_mean_squared_error: 5.5781
# Epoch 220/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0448 - mean_squared_error: 2.0448 - val_loss: 5.8606 - val_mean_squared_error: 5.8606
# Epoch 221/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.1726 - mean_squared_error: 2.1726 - val_loss: 5.2447 - val_mean_squared_error: 5.2447
# Epoch 222/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0188 - mean_squared_error: 2.0188 - val_loss: 5.1105 - val_mean_squared_error: 5.1105
# Epoch 223/250
# 12/12 [==============================] - 0s 11ms/step - loss: 2.0033 - mean_squared_error: 2.0033 - val_loss: 4.9516 - val_mean_squared_error: 4.9516
# Epoch 224/250
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0068 - mean_squared_error: 2.0068 - val_loss: 5.5052 - val_mean_squared_error: 5.5052
# Epoch 225/250
# 12/12 [==============================] - 0s 11ms/step - loss: 1.9301 - mean_squared_error: 1.9301 - val_loss: 5.5122 - val_mean_squared_error: 5.5122
# Epoch 226/250
# 12/12 [==============================] - 0s 10ms/step - loss: 1.9321 - mean_squared_error: 1.9321 - val_loss: 5.2908 - val_mean_squared_error: 5.2908
# Epoch 227/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1376 - mean_squared_error: 2.1376 - val_loss: 4.8229 - val_mean_squared_error: 4.8229
# Epoch 228/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.8806 - mean_squared_error: 1.8806 - val_loss: 6.1352 - val_mean_squared_error: 6.1352
# Epoch 229/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9156 - mean_squared_error: 1.9156 - val_loss: 4.9575 - val_mean_squared_error: 4.9575
# Epoch 230/250
# 12/12 [==============================] - 0s 7ms/step - loss: 1.9220 - mean_squared_error: 1.9220 - val_loss: 5.2923 - val_mean_squared_error: 5.2923
# Epoch 231/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.1033 - mean_squared_error: 2.1033 - val_loss: 5.2402 - val_mean_squared_error: 5.2402
# Epoch 232/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.0642 - mean_squared_error: 2.0642 - val_loss: 5.7037 - val_mean_squared_error: 5.7037
# Epoch 233/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9958 - mean_squared_error: 1.9958 - val_loss: 6.0426 - val_mean_squared_error: 6.0426
# Epoch 234/250
# 12/12 [==============================] - 0s 7ms/step - loss: 2.1963 - mean_squared_error: 2.1963 - val_loss: 5.5758 - val_mean_squared_error: 5.5758
# Epoch 235/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1166 - mean_squared_error: 2.1166 - val_loss: 5.7026 - val_mean_squared_error: 5.7026
# Epoch 236/250
# 12/12 [==============================] - 0s 6ms/step - loss: 2.0105 - mean_squared_error: 2.0105 - val_loss: 5.0903 - val_mean_squared_error: 5.0903
# Epoch 237/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.8241 - mean_squared_error: 1.8241 - val_loss: 5.8403 - val_mean_squared_error: 5.8403
# Epoch 238/250
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8499 - mean_squared_error: 1.8499 - val_loss: 5.2138 - val_mean_squared_error: 5.2138
# Epoch 239/250
# 12/12 [==============================] - 0s 7ms/step - loss: 1.9325 - mean_squared_error: 1.9325 - val_loss: 5.1827 - val_mean_squared_error: 5.1827
# Epoch 240/250
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8126 - mean_squared_error: 1.8126 - val_loss: 5.4670 - val_mean_squared_error: 5.4670
# Epoch 241/250
# 12/12 [==============================] - 0s 7ms/step - loss: 1.9072 - mean_squared_error: 1.9072 - val_loss: 5.1775 - val_mean_squared_error: 5.1775
# Epoch 242/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7616 - mean_squared_error: 1.7616 - val_loss: 5.9036 - val_mean_squared_error: 5.9036
# Epoch 243/250
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7848 - mean_squared_error: 1.7848 - val_loss: 5.0532 - val_mean_squared_error: 5.0532
# Epoch 244/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7591 - mean_squared_error: 1.7591 - val_loss: 5.0578 - val_mean_squared_error: 5.0578
# Epoch 245/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7111 - mean_squared_error: 1.7111 - val_loss: 5.6463 - val_mean_squared_error: 5.6463
# Epoch 246/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9182 - mean_squared_error: 1.9182 - val_loss: 5.0088 - val_mean_squared_error: 5.0088
# Epoch 247/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9359 - mean_squared_error: 1.9359 - val_loss: 5.1463 - val_mean_squared_error: 5.1463
# Epoch 248/250
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6732 - mean_squared_error: 1.6732 - val_loss: 5.1228 - val_mean_squared_error: 5.1228
# Epoch 249/250
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6742 - mean_squared_error: 1.6742 - val_loss: 5.0294 - val_mean_squared_error: 5.0294
# Epoch 250/250
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8051 - mean_squared_error: 1.8051 - val_loss: 5.0277 - val_mean_squared_error: 5.0277

# %% [markdown]
# ### Answer 6
#
# - MSE: slower convergence in some cases
# - MAE: less sensitive to outliers
# - MSLE: less sensitive to large errors

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md

# %% [markdown]
# #Fun Fact
#
# Google Translate is getting better all the time, but it's still not perfect. Translate a sentence into another language and back into English, and you might get a hilarious surprise. That's what Malinda Kathleen Reese got when she reverse Google Translated the lyrics to "Let It Go" from Disney's Frozen into Chinese, Macedonian, French, Polish, Creole, Tamil and others. It doesn't come out as utter gibberish, but as a slightly off version with a slightly different message from the original. Which makes it even funnier. Plus, Malinda can really sing.
#
# Link to video: https://www.youtube.com/watch?v=2bVAoVlFYf0

# %% [markdown]
# #References
#
# https://towardsdatascience.com/common-loss-functions-in-machine-learning-46af0ffc4d23
#
# https://peltarion.com/knowledge-center/documentation/modeling-view/build-an-ai-model/loss-functions/mean-squared-logarithmic-error-(msle)
